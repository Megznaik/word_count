# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Python/Dataset/chatGPT.csv"

# %%
dataset = pd.read_csv(path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset.head()
# Out:
#                                                tweet        user_name  \
# 0  Only 17% of people say they've tried using sof...  mike_greenfield
# 1  Latest #SouthPark amusingly tackles ChatGPT- w...  brettbirddotnet
# 2  @Barnacules @johnvianny Just trying to get the...       aidevcodes
# 3  Google search is bad and getting worse. Here's...         DataJoeG
# 4  RT @AiHandbook: ChatGPT can triple productivit...      MaggsAnstey
#
#                   location
# 0                Palo Alto
# 1                      NaN
# 2                      NaN
# 3               Texas, USA
# 4  England, United Kingdom

# %% [markdown]
# #Mini Project 1: Text summary

# %%
text = """The book is structured around the metaphor of a staircase, where each step represents a critical element of reaching personal and professional success. The first step, according to Ziglar, is Self-Image. He emphasizes the importance of having a positive self-image and how it is foundational to achieving anything meaningful in life.

The next step is building good Character, followed by the significance of having the right Attitude. Ziglar suggests that a positive attitude enables you to face challenges head-on and is instrumental in achieving success.

Work and effort are also major themes in the book. Ziglar emphasizes that setting Goals is another critical step on the staircase. Without goals, according to him, it's easy to drift aimlessly through life. He encourages the reader to write down their short-term and long-term goals and devise action plans to achieve them.

Interpersonal relationships and creating a healthy environment by being around positive, uplifting people is another point that Ziglar covers. The book delves into various aspects of human psychology and social interactions that can either elevate you or bring you down.

Lastly, Ziglar discusses Desire, the final step on the staircase. He argues that without a burning desire to achieve your goals, all the other steps are inconsequential. Ziglar doesn't just present abstract ideas; he provides practical advice and actionable steps one can take to start climbing their personal staircase to the top."""

# %%
# Count the frequency of each word from corpus
# Deal with stopwords(is,in,the)
# Visualize with wordcloud

# %% [markdown]
# # Count frequency

# %%
dict = {}

for i in text.split():
  i= i.lower().strip()
  if i not in dict:
    dict[i] = 1
  else:
    dict[i] += 1
print(dict)
count= sum(dict.values())
print(count)
# Out:
# {'the': 15, 'book': 2, 'is': 7, 'structured': 1, 'around': 2, 'metaphor': 1, 'of': 5, 'a': 6, 'staircase,': 1, 'where': 1, 'each': 1, 'step': 4, 'represents': 1, 'critical': 2, 'element': 1, 'reaching': 1, 'personal': 2, 'and': 9, 'professional': 1, 'success.': 2, 'first': 1, 'step,': 1, 'according': 2, 'to': 10, 'ziglar,': 1, 'self-image.': 1, 'he': 4, 'emphasizes': 2, 'importance': 1, 'having': 2, 'positive': 2, 'self-image': 1, 'how': 1, 'it': 1, 'foundational': 1, 'achieving': 2, 'anything': 1, 'meaningful': 1, 'in': 3, 'life.': 2, 'next': 1, 'building': 1, 'good': 1, 'character,': 1, 'followed': 1, 'by': 2, 'significance': 1, 'right': 1, 'attitude.': 1, 'ziglar': 5, 'suggests': 1, 'that': 5, 'attitude': 1, 'enables': 1, 'you': 3, 'face': 1, 'challenges': 1, 'head-on': 1, 'instrumental': 1, 'work': 1, 'effort': 1, 'are': 2, 'also': 1, 'major': 1, 'themes': 1, 'book.': 1, 'setting': 1, 'goals': 2, 'another': 2, 'on': 2, 'staircase.': 2, 'without': 2, 'goals,': 2, 'him,': 1, "it's": 1, 'easy': 1, 'drift': 1, 'aimlessly': 1, 'through': 1, 'encourages': 1, 'reader': 1, 'write': 1, 'down': 1, 'their': 2, 'short-term': 1, 'long-term': 1, 'devise': 1, 'action': 1, 'plans': 1, 'achieve': 2, 'them.': 1, 'interpersonal': 1, 'relationships': 1, 'creating': 1, 'healthy': 1, 'environment': 1, 'being': 1, 'positive,': 1, 'uplifting': 1, 'people': 1, 'point': 1, 'covers.': 1, 'delves': 1, 'into': 1, 'various': 1, 'aspects': 1, 'human': 1, 'psychology': 1, 'social': 1, 'interactions': 1, 'can': 2, 'either': 1, 'elevate': 1, 'or': 1, 'bring': 1, 'down.': 1, 'lastly,': 1, 'discusses': 1, 'desire,': 1, 'final': 1, 'argues': 1, 'burning': 1, 'desire': 1, 'your': 1, 'all': 1, 'other': 1, 'steps': 2, 'inconsequential.': 1, "doesn't": 1, 'just': 1, 'present': 1, 'abstract': 1, 'ideas;': 1, 'provides': 1, 'practical': 1, 'advice': 1, 'actionable': 1, 'one': 1, 'take': 1, 'start': 1, 'climbing': 1, 'staircase': 1, 'top.': 1}
# 230

# %% [markdown]
# #Stopwords

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re

# %%
nltk.download('stopwords')
stop_word = set(stopwords.words('english'))
print(f"Number of stopwords: {len(stop_word)}")
print(stop_word)
stop_word.update(['book','ziglar',])
print(f"Number of stopwords: {len(stop_word)}")
print(stop_word)
# Out:
# Number of stopwords: 179
# {'out', 'ours', 'where', 'hasn', 'by', "should've", 'this', 'll', 'those', 'who', 'off', 'having', 'been', 'ourselves', 'here', 've', 'most', 'd', 'down', 'for', 'what', 'y', 'herself', 'i', 'doing', 'more', "aren't", 'of', 'are', 'such', "she's", 'will', 'them', 'these', "doesn't", 'don', "mightn't", "weren't", 'a', 'which', "couldn't", 'do', 'over', 'couldn', 'doesn', "hasn't", 'mustn', 'needn', 'itself', 'or', "mustn't", 'it', 'myself', "you've", 'yours', 'hers', "shouldn't", 'no', 'against', 'all', 'just', 'they', 'your', 'few', 's', 'has', 'after', 'shan', 'am', 'hadn', 'while', 'how', 'did', 'only', 'ma', 'further', 'its', "you'd", 'before', 'you', 'isn', 'at', 'why', 'in', 'does', 'same', 'but', 'with', 'from', 'each', 'when', 'very', 'until', 'was', 'than', 'my', 'again', 'aren', 'm', 'her', 'me', 'she', "it's", "don't", 'his', "you're", 'both', 're', "wouldn't", 'themselves', 'into', 'yourselves', "shan't", 'theirs', 'under', 'and', "won't", 'be', 'now', 'nor', 'up', "hadn't", "you'll", 'because', 'didn', 'below', "haven't", 'should', 'then', 'whom', 'won', 'during', 'is', 'any', 'their', 'once', 'other', 'wouldn', 'about', 'that', 'yourself', 'through', 'were', 'above', "isn't", 'himself', 'the', 'as', 'some', 'weren', 'an', 'wasn', 'on', 'o', 'shouldn', 'had', 'being', 'haven', 'too', 'between', 'not', 'have', 'own', "that'll", 'ain', 'there', "needn't", 'our', 't', "wasn't", 'him', 'so', 'we', 'if', 'to', 'he', 'can', 'mightn', "didn't"}
# Number of stopwords: 181
# {'out', 'ours', 'where', 'hasn', 'by', "should've", 'this', 'll', 'those', 'who', 'off', 'having', 'been', 'ourselves', 'here', 've', 'most', 'd', 'down', 'for', 'what', 'y', 'herself', 'i', 'doing', 'more', "aren't", 'of', 'are', 'such', "she's", 'will', 'them', 'these', "doesn't", 'don', "mightn't", "weren't", 'a', 'which', "couldn't", 'do', 'over', 'couldn', 'doesn', "hasn't", 'mustn', 'needn', 'itself', 'or', "mustn't", 'it', 'myself', "you've", 'yours', 'hers', "shouldn't", 'no', 'against', 'all', 'just', 'they', 'your', 'few', 's', 'has', 'after', 'shan', 'am', 'hadn', 'while', 'how', 'did', 'only', 'ma', 'further', 'its', "you'd", 'before', 'you', 'isn', 'at', 'why', 'in', 'does', 'same', 'but', 'with', 'from', 'each', 'when', 'very', 'until', 'was', 'than', 'my', 'again', 'aren', 'm', 'her', 'me', 'she', "it's", "don't", 'his', "you're", 'both', 're', "wouldn't", 'themselves', 'into', 'yourselves', "shan't", 'theirs', 'under', 'and', "won't", 'be', 'now', 'nor', 'up', "hadn't", 'book', "you'll", 'because', 'didn', 'below', "haven't", 'should', 'then', 'whom', 'won', 'during', 'is', 'any', 'their', 'once', 'other', 'wouldn', 'about', 'that', 'yourself', 'through', 'were', 'above', "isn't", 'himself', 'the', 'as', 'some', 'weren', 'an', 'wasn', 'on', 'o', 'shouldn', 'had', 'being', 'haven', 'too', 'between', 'not', 'have', 'ziglar', 'own', "that'll", 'ain', 'there', "needn't", 'our', 't', "wasn't", 'him', 'so', 'we', 'if', 'to', 'he', 'can', 'mightn', "didn't"}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import string
st = ""
for i in text:
  if i not in string.punctuation:
    st += i
print(st)
# Out:
# The book is structured around the metaphor of a staircase where each step represents a critical element of reaching personal and professional success The first step according to Ziglar is SelfImage He emphasizes the importance of having a positive selfimage and how it is foundational to achieving anything meaningful in life
#
# The next step is building good Character followed by the significance of having the right Attitude Ziglar suggests that a positive attitude enables you to face challenges headon and is instrumental in achieving success
#
# Work and effort are also major themes in the book Ziglar emphasizes that setting Goals is another critical step on the staircase Without goals according to him its easy to drift aimlessly through life He encourages the reader to write down their shortterm and longterm goals and devise action plans to achieve them
#
# Interpersonal relationships and creating a healthy environment by being around positive uplifting people is another point that Ziglar covers The book delves into various aspects of human psychology and social interactions that can either elevate you or bring you down
#
# Lastly Ziglar discusses Desire the final step on the staircase He argues that without a burning desire to achieve your goals all the other steps are inconsequential Ziglar doesnt just present abstract ideas he provides practical advice and actionable steps one can take to start climbing their personal staircase to the top

# %%
filtered_text = " ".join([word for word in st.split() if word.lower() not in stop_word])
filtered_text
# Out:
# 'structured around metaphor staircase step represents critical element reaching personal professional success first step according SelfImage emphasizes importance positive selfimage foundational achieving anything meaningful life next step building good Character followed significance right Attitude suggests positive attitude enables face challenges headon instrumental achieving success Work effort also major themes emphasizes setting Goals another critical step staircase Without goals according easy drift aimlessly life encourages reader write shortterm longterm goals devise action plans achieve Interpersonal relationships creating healthy environment around positive uplifting people another point covers delves various aspects human psychology social interactions either elevate bring Lastly discusses Desire final step staircase argues without burning desire achieve goals steps inconsequential doesnt present abstract ideas provides practical advice actionable steps one take start climbing personal staircase top'

# %%
dict = {}

for i in filtered_text.split():
  i= i.lower().strip()
  if i not in dict:
    dict[i] = 1
  else:
    dict[i] += 1
print(dict)
count= sum(dict.values())
print(count)
# Out:
# {'structured': 1, 'around': 2, 'metaphor': 1, 'staircase': 4, 'step': 5, 'represents': 1, 'critical': 2, 'element': 1, 'reaching': 1, 'personal': 2, 'professional': 1, 'success': 2, 'first': 1, 'according': 2, 'selfimage': 2, 'emphasizes': 2, 'importance': 1, 'positive': 3, 'foundational': 1, 'achieving': 2, 'anything': 1, 'meaningful': 1, 'life': 2, 'next': 1, 'building': 1, 'good': 1, 'character': 1, 'followed': 1, 'significance': 1, 'right': 1, 'attitude': 2, 'suggests': 1, 'enables': 1, 'face': 1, 'challenges': 1, 'headon': 1, 'instrumental': 1, 'work': 1, 'effort': 1, 'also': 1, 'major': 1, 'themes': 1, 'setting': 1, 'goals': 4, 'another': 2, 'without': 2, 'easy': 1, 'drift': 1, 'aimlessly': 1, 'encourages': 1, 'reader': 1, 'write': 1, 'shortterm': 1, 'longterm': 1, 'devise': 1, 'action': 1, 'plans': 1, 'achieve': 2, 'interpersonal': 1, 'relationships': 1, 'creating': 1, 'healthy': 1, 'environment': 1, 'uplifting': 1, 'people': 1, 'point': 1, 'covers': 1, 'delves': 1, 'various': 1, 'aspects': 1, 'human': 1, 'psychology': 1, 'social': 1, 'interactions': 1, 'either': 1, 'elevate': 1, 'bring': 1, 'lastly': 1, 'discusses': 1, 'desire': 2, 'final': 1, 'argues': 1, 'burning': 1, 'steps': 2, 'inconsequential': 1, 'doesnt': 1, 'present': 1, 'abstract': 1, 'ideas': 1, 'provides': 1, 'practical': 1, 'advice': 1, 'actionable': 1, 'one': 1, 'take': 1, 'start': 1, 'climbing': 1, 'top': 1}
# 125

# %% [markdown]
# #Visualization

# %%
plt.figure(figsize= (10,8))
plt.imshow(WordCloud(background_color="yellow").generate(filtered_text))
plt.axis("off")
plt.show()
